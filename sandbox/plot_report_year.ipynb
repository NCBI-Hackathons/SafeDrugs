# %%
import matplotlib as mpl
# %matplotlib inline
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from quilt.data.hsiaoyi0504 import aeolus_top5drugs
# Out:
# /usr/local/Cellar/python/3.6.5_1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = pd.read_feather(aeolus_top5drugs.aeolus_top5drugs._data())
df.columns
# Out:
# Index(['id', 'master_age', 'deceased', 'age_code', 'gender_code',
#        'report_year', 'drug_concept_id', 'outcome_concept_id', 'age_cat',
#        'atc_1st', 'atc_2nd', 'atc_3rd', 'atc_4th', 'outcome_domain_id',
#        'drug_concept_name', 'outcome_concept_name', 'drug_outcome_name'],
#       dtype='object')

# %%
def plot_report_year():
    df = pd.read_feather(aeolus_top5drugs.aeolus_top5drugs._data())
    
    mpl.style.use('seaborn-whitegrid')
    mpl.rcParams['font.weight']= 'bold'
    mpl.rcParams['font.size']= 16
    
    data_group_by_y = df.groupby("report_year")["id"].count()
    
    _, ax = plt.subplots(figsize=(10, 10))
    
    p = data_group_by_y.plot(kind = "bar", ax=ax)
    p = ax.set_xlabel("Report Year")
    p = ax.set_ylabel("Reports")
    p = ax.set_xticklabels(ax.get_xticklabels(),rotation=45)

# %%
plot_report_year()
